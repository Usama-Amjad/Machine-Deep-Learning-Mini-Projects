# %%
import pandas as pd

# %%
car_make= pd.Series(["Honda","Toyota"])

# %%
color=pd.Series(['Red','Grey'])

# %%
car_make
# Out:
# 0     Honda
# 1    Toyota
# dtype: object

# %%
color
# Out:
# 0     Red
# 1    Grey
# dtype: object

# %%
Car_info=pd.DataFrame({'Car Make':car_make,'Car Color':color})

# %%
Car_info
# Out:
#   Car Make Car Color
# 0    Honda       Red
# 1   Toyota      Grey

# %%
car_sale=pd.read_csv('car-sales.csv')

# %%
car_sale
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sale.to_csv("exported_file_sales.csv",index=False)

# %%
car_sales2=pd.read_csv('exported_file_sales.csv')
car_sales2
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
foods=pd.Series(['Toast','Spaghetti','Rice'])

# %%
price=pd.Series([12,34,51])

# %%
menu=pd.DataFrame({'Dish Name':foods,'Price':price})

# %%
menu
# Out:
#    Dish Name  Price
# 0      Toast     12
# 1  Spaghetti     34
# 2       Rice     51

# %%
heart_disease=pd.read_csv('heart_disease.csv')

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
heart_disease.to_csv('heart_diseases_list.csv',index=False)

# %%
df=pd.read_csv("heart_diseases_list.csv")

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# ...

# %%
# df['age'].mean
df.age.mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64>

# %%
dfc=df.columns

# %%
dfc
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
dfc[1]
# Out:
# 'sex'

# %%
car_sales2
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales2[car_sales2['Make']=='Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales2.to_csv('car_sales.csv',index=False)

# %%
car_sales=pd.read_csv('car_sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales[car_sales.Make=="Honda"]
# Out:
#     Make Colour  Odometer (KM)  Doors      Price
# 1  Honda    Red          87899      4  $5,000.00
# 6  Honda   Blue          45698      4  $7,500.00
# 7  Honda   Blue          54738      4  $7,000.00

# %%
car_sales[car_sales.Colour=="White"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales[car_sales['Odometer (KM)']<100000]
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.Doors.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Odometer (KM)'}>,
#         <AxesSubplot:title={'center':'Doors'}>],
#        [<AxesSubplot:title={'center':'Price'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
car_sales['Odometer (KM)'].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales.Price.dtype
car_sales.Price
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
# car_sales.Price=car_sales.Price.str.replace('[\$\,\.]','').astype(int)

# %%
# car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)
car_sales.Price
# Out:
# 0     400000
# 1     500000
# 2     700000
# 3    2200000
# 4     350000
# 5     450000
# 6     750000
# 7     700000
# 8     625000
# 9     970000
# Name: Price, dtype: int32

# %%
car_sales["Price"] = car_sales["Price"].astype(str).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales_missing=pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales['Seats']=pd.Series([5,5,5,5,3,2,5,3])

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    5.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    5.0
# 4  Nissan  White         213095      4   350000    3.0
# 5  Toyota  Green          99213      4   450000    2.0
# 6   Honda   Blue          45698      4   750000    5.0
# 7   Honda   Blue          54738      4   700000    3.0
# 8  Toyota  White          60000      4   625000    NaN
# 9  Nissan  White          31600      4   970000    NaN

# %%
car_sales.fillna(5,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    5.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    5.0
# 4  Nissan  White         213095      4   350000    3.0
# 5  Toyota  Green          99213      4   450000    2.0
# 6   Honda   Blue          45698      4   750000    5.0
# 7   Honda   Blue          54738      4   700000    3.0
# 8  Toyota  White          60000      4   625000    5.0
# 9  Nissan  White          31600      4   970000    5.0

# %%
car_sales["Fuel_per_KM"]=[8,7,9,5,4,7,8,6,7,8]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM
# 0  Toyota  White         150043      4   400000    5.0            8
# 1   Honda    Red          87899      4   500000    5.0            7
# 2  Toyota   Blue          32549      3   700000    5.0            9
# 3     BMW  Black          11179      5  2200000    5.0            5
# 4  Nissan  White         213095      4   350000    3.0            4
# 5  Toyota  Green          99213      4   450000    2.0            7
# 6   Honda   Blue          45698      4   750000    5.0            8
# 7   Honda   Blue          54738      4   700000    3.0            6
# 8  Toyota  White          60000      4   625000    5.0            7
# 9  Nissan  White          31600      4   970000    5.0            8

# %%
car_sales["Total-fuel"]=(car_sales['Odometer (KM)']/100)*car_sales.Fuel_per_KM

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM  \
# 0  Toyota  White         150043      4   400000    5.0            8
# 1   Honda    Red          87899      4   500000    5.0            7
# 2  Toyota   Blue          32549      3   700000    5.0            9
# 3     BMW  Black          11179      5  2200000    5.0            5
# 4  Nissan  White         213095      4   350000    3.0            4
# 5  Toyota  Green          99213      4   450000    2.0            7
# 6   Honda   Blue          45698      4   750000    5.0            8
# 7   Honda   Blue          54738      4   700000    3.0            6
# 8  Toyota  White          60000      4   625000    5.0            7
# 9  Nissan  White          31600      4   970000    5.0            8
#
#    Total-fuel
# 0    12003.44
# 1     6152.93
# 2     2929.41
# 3      558.95
# 4     8523.80
# 5     6944.91
# 6     3655.84
# 7     3284.28
# 8     4200.00
# 9     2528.00

# %%
car_sales['wheels']=4

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM  \
# 0  Toyota  White         150043      4   400000    5.0            8
# 1   Honda    Red          87899      4   500000    5.0            7
# 2  Toyota   Blue          32549      3   700000    5.0            9
# 3     BMW  Black          11179      5  2200000    5.0            5
# 4  Nissan  White         213095      4   350000    3.0            4
# 5  Toyota  Green          99213      4   450000    2.0            7
# 6   Honda   Blue          45698      4   750000    5.0            8
# 7   Honda   Blue          54738      4   700000    3.0            6
# 8  Toyota  White          60000      4   625000    5.0            7
# 9  Nissan  White          31600      4   970000    5.0            8
#
#    Total-fuel  wheels
# 0    12003.44       4
# 1     6152.93       4
# 2     2929.41       4
# 3      558.95       4
# 4     8523.80       4
# 5     6944.91       4
# 6     3655.84       4
# 7     3284.28       4
# ...

# %%
car_sales.drop('wheels',axis=1,inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM  \
# 0  Toyota  White         150043      4   400000    5.0            8
# 1   Honda    Red          87899      4   500000    5.0            7
# 2  Toyota   Blue          32549      3   700000    5.0            9
# 3     BMW  Black          11179      5  2200000    5.0            5
# 4  Nissan  White         213095      4   350000    3.0            4
# 5  Toyota  Green          99213      4   450000    2.0            7
# 6   Honda   Blue          45698      4   750000    5.0            8
# 7   Honda   Blue          54738      4   700000    3.0            6
# 8  Toyota  White          60000      4   625000    5.0            7
# 9  Nissan  White          31600      4   970000    5.0            8
#
#    Total-fuel
# 0    12003.44
# 1     6152.93
# 2     2929.41
# 3      558.95
# 4     8523.80
# 5     6944.91
# 6     3655.84
# 7     3284.28
# 8     4200.00
# 9     2528.00

# %%
car_sales['Odometer (KM)']=car_sales['Odometer (KM)'].apply(lambda x : x/1.6)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM  \
# 0  Toyota  White      93776.875      4   400000    5.0            8
# 1   Honda    Red      54936.875      4   500000    5.0            7
# 2  Toyota   Blue      20343.125      3   700000    5.0            9
# 3     BMW  Black       6986.875      5  2200000    5.0            5
# 4  Nissan  White     133184.375      4   350000    3.0            4
# 5  Toyota  Green      62008.125      4   450000    2.0            7
# 6   Honda   Blue      28561.250      4   750000    5.0            8
# 7   Honda   Blue      34211.250      4   700000    3.0            6
# 8  Toyota  White      37500.000      4   625000    5.0            7
# 9  Nissan  White      19750.000      4   970000    5.0            8
#
#    Total-fuel
# 0    12003.44
# 1     6152.93
# 2     2929.41
# 3      558.95
# 4     8523.80
# 5     6944.91
# 6     3655.84
# 7     3284.28
# 8     4200.00
# 9     2528.00

# %%
color1=pd.Series(["Red","Orannge","Yellow"])

# %%
color1
# Out:
# 0        Red
# 1    Orannge
# 2     Yellow
# dtype: object

# %%
cars=pd.Series(["BMW","Audi","Lambo"])

# %%
cars
# Out:
# 0      BMW
# 1     Audi
# 2    Lambo
# dtype: object

# %%
df=pd.DataFrame({'Make':cars,'color':color1})

# %%
df
# Out:
#     Make    color
# 0    BMW      Red
# 1   Audi  Orannge
# 2  Lambo   Yellow

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM  \
# 0  Toyota  White      93776.875      4   400000    5.0            8
# 1   Honda    Red      54936.875      4   500000    5.0            7
# 2  Toyota   Blue      20343.125      3   700000    5.0            9
# 3     BMW  Black       6986.875      5  2200000    5.0            5
# 4  Nissan  White     133184.375      4   350000    3.0            4
# 5  Toyota  Green      62008.125      4   450000    2.0            7
# 6   Honda   Blue      28561.250      4   750000    5.0            8
# 7   Honda   Blue      34211.250      4   700000    3.0            6
# 8  Toyota  White      37500.000      4   625000    5.0            7
# 9  Nissan  White      19750.000      4   970000    5.0            8
#
#    Total-fuel
# 0    12003.44
# 1     6152.93
# 2     2929.41
# 3      558.95
# 4     8523.80
# 5     6944.91
# 6     3655.84
# 7     3284.28
# 8     4200.00
# 9     2528.00

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [143], in <cell line: 1>()
# ----> 1 car_sales.dtype
#
# File ~\Desktop\project1\env\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
car_sales.to_csv('car_sales_exp.csv',index=False)

# %%
car__sales=pd.read_csv('car_sales_exp.csv')

# %%
car__sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM  \
# 0  Toyota  White         150043      4   400000    5.0            8
# 1   Honda    Red          87899      4   500000    5.0            7
# 2  Toyota   Blue          32549      3   700000    5.0            9
# 3     BMW  Black          11179      5  2200000    5.0            5
# 4  Nissan  White         213095      4   350000    3.0            4
# 5  Toyota  Green          99213      4   450000    2.0            7
# 6   Honda   Blue          45698      4   750000    5.0            8
# 7   Honda   Blue          54738      4   700000    3.0            6
# 8  Toyota  White          60000      4   625000    5.0            7
# 9  Nissan  White          31600      4   970000    5.0            8
#
#    Total-fuel
# 0    12003.44
# 1     6152.93
# 2     2929.41
# 3      558.95
# 4     8523.80
# 5     6944.91
# 6     3655.84
# 7     3284.28
# 8     4200.00
# 9     2528.00

# %%
car__sales.dtypes
# Out:
# Make              object
# Colour            object
# Odometer (KM)      int64
# Doors              int64
# Price              int64
# Seats            float64
# Fuel_per_KM        int64
# Total-fuel       float64
# dtype: object

# %%
car__sales.Price.mean()
# Out:
# 764500.0

# %%
car__sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price', 'Seats',
#        'Fuel_per_KM', 'Total-fuel'],
#       dtype='object')

# %%
len(car__sales)
# Out:
# 10

# %%
car_sales.loc[3]
car_sales.iloc[3]
# Out:
# Make                 BMW
# Colour             Black
# Odometer (KM)      11179
# Doors                  5
# Price            2200000
# Seats                5.0
# Fuel_per_KM            5
# Total-fuel        558.95
# Name: 3, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM  \
# 0  Toyota  White      93776.875      4   400000    5.0            8
# 1   Honda    Red      54936.875      4   500000    5.0            7
# 2  Toyota   Blue      20343.125      3   700000    5.0            9
# 3     BMW  Black       6986.875      5  2200000    5.0            5
# 4  Nissan  White     133184.375      4   350000    3.0            4
# 5  Toyota  Green      62008.125      4   450000    2.0            7
# 6   Honda   Blue      28561.250      4   750000    5.0            8
# 7   Honda   Blue      34211.250      4   700000    3.0            6
# 8  Toyota  White      37500.000      4   625000    5.0            7
# 9  Nissan  White      19750.000      4   970000    5.0            8
#
#    Total-fuel
# 0    12003.44
# 1     6152.93
# 2     2929.41
# 3      558.95
# 4     8523.80
# 5     6944.91
# 6     3655.84
# 7     3284.28
# 8     4200.00
# 9     2528.00

# %%
car_sales[car_sales["Odometer (KM)"]<10000]
# Out:
#   Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM  Total-fuel
# 3  BMW  Black       6986.875      5  2200000    5.0            5      558.95

# %%
car_sales.Price=car_sales.Price/100

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel_per_KM  \
# 0  Toyota  White      93776.875      4   4000.0    5.0            8
# 1   Honda    Red      54936.875      4   5000.0    5.0            7
# 2  Toyota   Blue      20343.125      3   7000.0    5.0            9
# 3     BMW  Black       6986.875      5  22000.0    5.0            5
# 4  Nissan  White     133184.375      4   3500.0    3.0            4
# 5  Toyota  Green      62008.125      4   4500.0    2.0            7
# 6   Honda   Blue      28561.250      4   7500.0    5.0            8
# 7   Honda   Blue      34211.250      4   7000.0    3.0            6
# 8  Toyota  White      37500.000      4   6250.0    5.0            7
# 9  Nissan  White      19750.000      4   9700.0    5.0            8
#
#    Total-fuel
# 0    12003.44
# 1     6152.93
# 2     2929.41
# 3      558.95
# 4     8523.80
# 5     6944.91
# 6     3655.84
# 7     3284.28
# 8     4200.00
# 9     2528.00

# %%
car_sales["Odometer (KM)"]=car_sales["Odometer (M)"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Desktop\project1\env\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\Desktop\project1\env\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Desktop\project1\env\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Odometer (M)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
car_sales.rename(columns={"Odometer (KM)":"Odometer (M)"},inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (M)  Doors    Price  Seats  Fuel_per_KM  Total-fuel
# 0  Toyota  White     93776.875      4   4000.0    5.0            8    12003.44
# 1   Honda    Red     54936.875      4   5000.0    5.0            7     6152.93
# 2  Toyota   Blue     20343.125      3   7000.0    5.0            9     2929.41
# 3     BMW  Black      6986.875      5  22000.0    5.0            5      558.95
# 4  Nissan  White    133184.375      4   3500.0    3.0            4     8523.80
# 5  Toyota  Green     62008.125      4   4500.0    2.0            7     6944.91
# 6   Honda   Blue     28561.250      4   7500.0    5.0            8     3655.84
# 7   Honda   Blue     34211.250      4   7000.0    3.0            6     3284.28
# 8  Toyota  White     37500.000      4   6250.0    5.0            7     4200.00
# 9  Nissan  White     19750.000      4   9700.0    5.0            8     2528.00
